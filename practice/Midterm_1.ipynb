# %%
#1. 데이터 띄우기
import pandas as pd
import numpy as np

df = pd.read_csv('CARD_SUBWAY_MONTH_202501.csv')
new=df.to_numpy()
new

df=pd.DataFrame(new, columns=['노선명', '역명', '승차총승객수', '하차총승객수', '등록일자',0])
df.drop(columns=[0], inplace=True)
print(df.info())

print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19129 entries, 0 to 19128
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노선명     19129 non-null  object
#  1   역명      19129 non-null  object
#  2   승차총승객수  19129 non-null  object
#  3   하차총승객수  19129 non-null  object
#  4   등록일자    19129 non-null  object
# dtypes: object(5)
# memory usage: 747.4+ KB
# None
# 노선명       0
# 역명        0
# 승차총승객수    0
# 하차총승객수    0
# 등록일자      0
# dtype: int64

# %%
#3. 데이터 관리

df = pd.read_csv('CARD_SUBWAY_MONTH_202501.csv')
new=df.to_numpy()
new

df=pd.DataFrame(new, columns=['노선명', '역명', '승차총승객수', '하차총승객수', '등록일자',0])
df.drop(columns=[0], inplace=True)
#3-1. 정규화
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['승차총승객수', '하차총승객수']] = scaler.fit_transform(df[['승차총승객수','하차총승객수']])

#3-2. 파생변수
df['승하차비율'] = df['승차총승객수'] / (df['하차총승객수'] + 1e-6)


df
# Out:
#        노선명           역명    승차총승객수    하차총승객수      등록일자     승하차비율
# 0      수인선           송도 -0.792417 -0.792725  20250104  0.999613
# 1      4호선           창동  0.251740  0.340716  20250104  0.738855
# 2      4호선           쌍문  0.281576  0.227343  20250104  1.238544
# 3      4호선     수유(강북구청)  0.737543  0.718998  20250104  1.025791
# 4      4호선  미아(서울사이버대학) -0.284167 -0.304071  20250104  0.934545
# ...    ...          ...       ...       ...       ...       ...
# 19124  수인선      남동인더스파크 -0.776410 -0.752684  20250203  1.031524
# 19125  수인선          원인재 -0.566897 -0.546945  20250203  1.036481
# 19126  수인선           연수 -0.535072 -0.540005  20250203  0.990866
# 19127  수인선           송도 -0.733409 -0.743306  20250203  0.986686
# 19128  수인선          인하대 -0.433251 -0.461423  20250203  0.938948
#
# [19129 rows x 6 columns]

# %%
#3-3. encoder
df['노선명'].value_counts()
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['노선명'] = encoder.fit_transform(df['노선명'])

df['역명'] = encoder.fit_transform(df['역명'])
df
# Out:
#        노선명   역명    승차총승객수    하차총승객수      등록일자     승하차비율
# 0       20  278 -0.792417 -0.792725  20250104  0.999613
# 1        3  464  0.251740  0.340716  20250104  0.738855
# 2        3  324  0.281576  0.227343  20250104  1.238544
# 3        3  290  0.737543  0.718998  20250104  1.025791
# 4        3  179 -0.284167 -0.304071  20250104  0.934545
# ...    ...  ...       ...       ...       ...       ...
# 19124   20   83 -0.776410 -0.752684  20250203  1.031524
# 19125   20  396 -0.566897 -0.546945  20250203  1.036481
# 19126   20  360 -0.535072 -0.540005  20250203  0.990866
# 19127   20  278 -0.733409 -0.743306  20250203  0.986686
# 19128   20  422 -0.433251 -0.461423  20250203  0.938948
#
# [19129 rows x 6 columns]

# %%
#4. 파이프라인
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
df = pd.read_csv('CARD_SUBWAY_MONTH_202501.csv')
new=df.to_numpy()
new

df=pd.DataFrame(new, columns=['노선명', '역명', '승차총승객수', '하차총승객수', '등록일자',0])
df.drop(columns=[0], inplace=True)

def preprocessor(df):
  #3-1. 정규화
  scaler = StandardScaler()
  df[['승차총승객수', '하차총승객수']] = scaler.fit_transform(df[['승차총승객수','하차총승객수']])

  #3-2. 파생변수
  df['승하차비율'] = df['승차총승객수'] / (df['하차총승객수'] + 1e-6)
  #3-3. encoder
  df['노선명'].value_counts()
  encoder = LabelEncoder()
  df['노선명'] = encoder.fit_transform(df['노선명'])
  df['역명'] = encoder.fit_transform(df['역명'])

  return df



df=preprocessor(df)
df

df.to_csv('processed_df.csv')
